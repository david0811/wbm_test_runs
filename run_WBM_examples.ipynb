# %%
import os
import subprocess

import pandas as pd
from run_WBM import run_WBM

# %%
# Read all climate drivers
df_climate_drivers = pd.read_csv("./utils/climate_drivers.csv")

# %%
######################
# Common to all runs #
######################

# Main directory
main_path = "/gpfs/group/kaf26/default/dcl5300/wbm_soilM_crop_uc_lafferty-etal-2024-tbd_DATA/wbm/"

# Output variables
output_vars = ["soilMoist", "soilMoistFrac"]

# PET method
pet_method = "Hamon"

# Rooting depth
rootingDepth = "Effective_Rooting_Depth_mod.init"

# Available water capacity
# soilAWC = "/gpfs/group/kaf26/default/private/WBM_data/squam.sr.unh.edu/US_CDL_v3_data/soil/SSURGO_SoilData_awc_frac_mm_m_CONUS_1km.tif"
soilAWC = "SSURGO_HARMON_AWC_05min_NAM_US.init"

# Canopy height
canopyHt = "/gpfs/group/kaf26/default/private/WBM_data/squam.sr.unh.edu/US_CDL_v3_data/canopy/Simard_Pinto_3DGlobalVeg_JGR_10km.tif"

# Leaf Area Index
lai = "merra2_lai2_dc.init"

# Lan collapse method
land_collapse = "average"

# Project ID
project_ID = "PCHES_crop_yield_UC_climate_param"

# %% [markdown]
# # Historical runs (observational data)

# %%
#######################
# Common to hist runs #
#######################

# Simulation length
run_start = "1980-01-01"
run_end = "2014-12-31"

# Spinup
spinup_start = "1980-01-01"
spinup_end = "1980-12-31"
spinup_loops = 5

# Cloud fraction
cloudFr_primary = "merra2_cldtot_d.init"

# Crop parameter file
crop_par = "CDL-US-M_CropParameters_hist.csv"

# Crop area timeseries
crop_area_frac = "cdl_cropland_hist.init"

# %%
########
# GMFD #
########
run_WBM(
    run_type="obs",
    main_path=main_path,
    sim_ID="OBS_GMFD_historical",
    model_info={},
    project_ID=project_ID,
    run_start=run_start,
    run_end=run_end,
    spinup_start=spinup_start,
    spinup_end=spinup_end,
    spinup_loops=spinup_loops,
    output_vars=output_vars,
    pet_method=pet_method,
    airT_primary="GMFD_tas_daily.init",
    airT_secondary="",
    airT_min="",
    airT_max="",
    precip_primary="GMFD_prcp_daily.init",
    precip_secondary="",
    cloudFr_primary=cloudFr_primary,
    windU_primary="",
    windV_primary="",
    humidity_primary="",
    albedo_primary="",
    rootingDepth=rootingDepth,
    soilAWC=soilAWC,
    canopyHt=canopyHt,
    lai=lai,
    land_collapse=land_collapse,
    crop_area_frac=crop_area_frac,
    crop_area_frac_patch="",
    crop_par=crop_par,
    crop_par_patch="",
)
# Out:
# check jobid: 44106071
# spool jobid: 44106096
# run jobid: 44106098

# %%
###########
# Livneh2 #
###########
run_WBM(
    run_type="obs",
    main_path=main_path,
    sim_ID="OBS_Livneh2_historical",
    model_info={},
    project_ID=project_ID,
    run_start=run_start,
    run_end=run_end,
    spinup_start=spinup_start,
    spinup_end=spinup_end,
    spinup_loops=spinup_loops,
    output_vars=output_vars,
    pet_method=pet_method,
    airT_primary="XXX",
    airT_secondary="XXX",
    airT_min="Livneh2_Tmax_daily.init",
    airT_max="Livneh2_Tmin_daily.init",
    precip_primary="Livneh2_precip_daily.init",
    precip_secondary="",
    cloudFr_primary=cloudFr_primary,
    windU_primary="",
    windV_primary="",
    humidity_primary="",
    albedo_primary="",
    rootingDepth=rootingDepth,
    soilAWC=soilAWC,
    canopyHt=canopyHt,
    lai=lai,
    land_collapse=land_collapse,
    crop_area_frac=crop_area_frac,
    crop_area_frac_patch="",
    crop_par=crop_par,
    crop_par_patch="",
)
# Out:
# check jobid: 44106100
# spool jobid: 44106122
# run jobid: 44106123

# %%
###########
# gridMET #
###########
run_WBM(
    run_type="obs",
    main_path=main_path,
    sim_ID="OBS_gridMET_historical",
    model_info={},
    project_ID=project_ID,
    run_start=run_start,
    run_end=run_end,
    spinup_start=spinup_start,
    spinup_end=spinup_end,
    spinup_loops=spinup_loops,
    output_vars=output_vars,
    pet_method=pet_method,
    airT_primary="XXX",
    airT_secondary="XXX",
    airT_min="gridMET_tmmn_daily.init",
    airT_max="gridMET_tmmx_daily.init",
    precip_primary="gridMET_pr_daily.init",
    precip_secondary="",
    cloudFr_primary=cloudFr_primary,
    windU_primary="",
    windV_primary="",
    humidity_primary="",
    albedo_primary="",
    rootingDepth=rootingDepth,
    soilAWC=soilAWC,
    canopyHt=canopyHt,
    lai=lai,
    land_collapse=land_collapse,
    crop_area_frac=crop_area_frac,
    crop_area_frac_patch="",
    crop_par=crop_par,
    crop_par_patch="",
)
# Out:
# check jobid: 44106135
# spool jobid: 44106160
# run jobid: 44106162

# %%
#########
# PRISM #
#########
run_start = "1981-01-01"  # only PRISM

spinup_start = "1981-01-01"
spinup_end = "1981-12-31"
spinup_loops = 5

run_WBM(
    run_type="obs",
    main_path=main_path,
    sim_ID="OBS_PRISM_historical",
    model_info={},
    project_ID=project_ID,
    run_start=run_start,
    run_end=run_end,
    spinup_start=spinup_start,
    spinup_end=spinup_end,
    spinup_loops=spinup_loops,
    output_vars=output_vars,
    pet_method=pet_method,
    airT_primary="PRISM_tmean_4kmD2_d.init",
    airT_secondary="",
    airT_min="",
    airT_max="",
    precip_primary="PRISM_ppt_4kmD2_d.init",
    precip_secondary="",
    cloudFr_primary=cloudFr_primary,
    windU_primary="",
    windV_primary="",
    humidity_primary="",
    albedo_primary="",
    rootingDepth=rootingDepth,
    soilAWC=soilAWC,
    canopyHt=canopyHt,
    lai=lai,
    land_collapse=land_collapse,
    crop_area_frac=crop_area_frac,
    crop_area_frac_patch="",
    crop_par=crop_par,
    crop_par_patch="",
)
# Out:
# check jobid: 44106124
# spool jobid: 44106130
# run jobid: 44106132

# %% [markdown]
# # Hindcast runs (climate models)

# %%
#######################
# Common to hindcasts #
#######################

# Simulation length
run_start = "1980-01-01"
run_end = "2014-12-31"

# Spunup
spinup_start = "1980-01-01"
spinup_end = "1980-12-31"
spinup_loops = 5

# Cloud fraction
cloudFr_primary = "merra2_cldtot_d.init"

# Crop parameter file
crop_par = "CDL-US-M_CropParameters_hist.csv"

# Crop area timeseries
crop_area_frac = "cdl_cropland_hist.init"

# Only used for LOCA projections
state_id = ""

# %% [markdown]
# ### NEX-GDDP

# %%
# Constants
ensemble = "NEX-GDDP"
vars_ = ["tasmin", "tasmax", "pr"]

# Get run infos
run_info = df_climate_drivers[
    (df_climate_drivers.ensemble == ensemble) & (df_climate_drivers.ssp == "historical")
].copy()

# %%
#################
# NEX hindcasts #
#################
for _, info in run_info.iterrows():
    print(info["model"])
    sim_ID = f"{info['ensemble']}_{info['model']}_{info['member']}_{info['ssp']}"

    run_WBM(
        run_type="model",
        main_path=main_path,
        sim_ID=sim_ID,
        run_info=info,
        project_ID=project_ID,
        run_start=run_start,
        run_end=run_end,
        spinup_start=spinup_start,
        spinup_end=spinup_end,
        spinup_loops=spinup_loops,
        state_id=state_id,
        output_vars=output_vars,
        pet_method=pet_method,
        vars_=vars_,
        airT_primary="XXX",
        airT_secondary="XXX",
        airT_min=f"{sim_ID}_tasmin_daily.init",
        airT_max=f"{sim_ID}_tasmax_daily.init",
        precip_primary=f"{sim_ID}_pr_daily.init",
        precip_secondary="",
        cloudFr_primary=cloudFr_primary,
        windU_primary="",
        windV_primary="",
        humidity_primary="",
        albedo_primary="",
        rootingDepth=rootingDepth,
        soilAWC=soilAWC,
        canopyHt=canopyHt,
        lai=lai,
        land_collapse=land_collapse,
        crop_area_frac=crop_area_frac,
        crop_area_frac_patch="",
        crop_par=crop_par,
        crop_par_patch="",
    )

    print("\n")
# Out:
# IPSL-CM6A-LR
# check jobid: 44246829
# spool jobid: 44246832
# run jobid: 44246834
#
#
# ACCESS-CM2
# Directory already exists!
# spooling already done.
# run already done.
#
#
# GFDL-CM4_gr2
# check jobid: 44246835
# spool jobid: 44246836
# run jobid: 44246837
#
#
# INM-CM5-0
# check jobid: 44246838
# spool jobid: 44246842
# run jobid: 44246843
#
#
# KACE-1-0-G
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-LR
# check jobid: 44246844
# spool jobid: 44246845
# run jobid: 44246846
#
#
# NorESM2-LM
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CanESM5
# Directory already exists!
# spooling already done.
# run already done.
#
#
# UKESM1-0-LL
# Directory already exists!
# spooling already done.
# run already done.
#
#
# GFDL-ESM4
# check jobid: 44246847
# spool jobid: 44246849
# run jobid: 44246850
#
#
# ACCESS-ESM1-5
# check jobid: 44246851
# spool jobid: 44246855
# run jobid: 44246856
#
#
# GFDL-CM4
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MIROC-ES2L
# check jobid: 44246857
# spool jobid: 44246901
# run jobid: 44246902
#
#
# GISS-E2-1-G
# check jobid: 44246903
# spool jobid: 44246905
# run jobid: 44246906
#
#
# CMCC-ESM2
# Directory already exists!
# spooling already done.
# run already done.
#
#
# EC-Earth3-Veg-LR
# Directory already exists!
# spooling already done.
# run already done.
#
#
# INM-CM4-8
# check jobid: 44246907
# spool jobid: 44246910
# run jobid: 44246911
#
#
# KIOST-ESM
# Directory already exists!
# spooling already done.
# run already done.
#
#
# EC-Earth3
# check jobid: 44246912
# spool jobid: 44246916
# run jobid: 44246917
#
#
# BCC-CSM2-MR
# check jobid: 44246918
# Something went wrong!
#
#
# MPI-ESM1-2-HR
# Directory already exists!
# spooling already done.
# run already done.
#
#
# TaiESM1
# Directory already exists!
# spooling already done.
# run already done.
#
#
# HadGEM3-GC31-LL
# check jobid: 44246962
# spool jobid: 44246963
# run jobid: 44246964
#
#
# CNRM-CM6-1
# check jobid: 44246965
# spool jobid: 44246967
# run jobid: 44246968
#
#
# FGOALS-g3
# Directory already exists!
# spooling already done.
# run already done.
#
#
# HadGEM3-GC31-MM
# check jobid: 44246969
# spool jobid: 44246971
# run jobid: 44246972
#
#
# CMCC-CM2-SR5
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MIROC6
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CNRM-ESM2-1
# Directory already exists!
# spooling already done.
# run already done.
#
#
# NorESM2-MM
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MRI-ESM2-0
# Directory already exists!
# spooling already done.
# run already done.

# %% [markdown]
# ### LOCA2

# %%
# Constants
ensemble = "LOCA2"
vars_ = ["tasmax", "tasmin", "pr"]

# Get run infos
run_info = df_climate_drivers[
    (df_climate_drivers.ensemble == ensemble) & (df_climate_drivers.ssp == "historical")
].copy()

# %%
##################
# LOCA2 hindcasts
##################
for _, info in run_info.iterrows():
    print(f"{info['model']} {info['member']}")
    sim_ID = f"{ensemble}_{info['model']}_{info['member']}_{info['ssp']}"

    run_WBM(
        run_type="model",
        main_path=main_path,
        sim_ID=sim_ID,
        run_info=info,
        project_ID=project_ID,
        run_start=run_start,
        run_end=run_end,
        spinup_start=spinup_start,
        spinup_end=spinup_end,
        spinup_loops=spinup_loops,
        state_id=state_id,
        output_vars=output_vars,
        pet_method=pet_method,
        vars_=vars_,
        airT_primary="XXX",
        airT_secondary="XXX",
        airT_min=f"{sim_ID}_tasmin_daily.init",
        airT_max=f"{sim_ID}_tasmax_daily.init",
        precip_primary=f"{sim_ID}_pr_daily.init",
        precip_secondary="",
        cloudFr_primary=cloudFr_primary,
        windU_primary="",
        windV_primary="",
        humidity_primary="",
        albedo_primary="",
        rootingDepth=rootingDepth,
        soilAWC=soilAWC,
        canopyHt=canopyHt,
        lai=lai,
        land_collapse=land_collapse,
        crop_area_frac=crop_area_frac,
        crop_area_frac_patch="",
        crop_par=crop_par,
        crop_par_patch="",
    )

    print("\n")

# %% [markdown]
# ### OakRidge

# %%
# Get NEX historical run infos
run_info = df_climate_drivers[
    (df_climate_drivers.ensemble == "OakRidge") & (df_climate_drivers.ssp == "historical")
].copy()

# Constants
ensemble = "OakRidge"
vars_ = ["tmax", "tmin", "prcp"]

# %%
#####################
# OakRidge hindcasts
#####################
for _, info in run_info.iterrows():
    print(f"{info['model']} {info['method']}")
    sim_ID = f"{ensemble}_{info['model']}_{info['member']}_{info['method']}_{info['ssp']}"

    run_WBM(
        run_type="model",
        main_path=main_path,
        sim_ID=sim_ID,
        run_info=info,
        project_ID=project_ID,
        run_start=run_start,
        run_end=run_end,
        spinup_start=spinup_start,
        spinup_end=spinup_end,
        spinup_loops=spinup_loops,
        state_id=state_id,
        output_vars=output_vars,
        pet_method=pet_method,
        vars_=vars_,
        airT_primary="XXX",
        airT_secondary="XXX",
        airT_min=f"{sim_ID}_tmin_daily.init",
        airT_max=f"{sim_ID}_tmax_daily.init",
        precip_primary=f"{sim_ID}_prcp_daily.init",
        precip_secondary="",
        cloudFr_primary=cloudFr_primary,
        windU_primary="",
        windV_primary="",
        humidity_primary="",
        albedo_primary="",
        rootingDepth=rootingDepth,
        soilAWC=soilAWC,
        canopyHt=canopyHt,
        lai=lai,
        land_collapse=land_collapse,
        crop_area_frac=crop_area_frac,
        crop_area_frac_patch="",
        crop_par=crop_par,
        crop_par_patch="",
    )
    print("\n")
# Out:
# ACCESS-CM2 DBCCA_Daymet
# Directory already exists!
# spooling already done.
# run already done.
#
#
# BCC-CSM2-MR DBCCA_Daymet
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CNRM-ESM2-1 DBCCA_Daymet
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-HR DBCCA_Daymet
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MRI-ESM2-0 DBCCA_Daymet
# Directory already exists!
# spooling already done.
# run already done.
#
#
# NorESM2-MM DBCCA_Daymet
# Directory already exists!
# spooling already done.
# run already done.
#
#
# ACCESS-CM2 RegCM_Daymet
# Directory already exists!
# spooling already done.
# run already done.
#
#
# BCC-CSM2-MR RegCM_Daymet
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CNRM-ESM2-1 RegCM_Daymet
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-HR RegCM_Daymet
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MRI-ESM2-0 RegCM_Daymet
# Directory already exists!
# spooling already done.
# run already done.
#
#
# NorESM2-MM RegCM_Daymet
# Directory already exists!
# spooling already done.
# run already done.
#
#
# ACCESS-CM2 DBCCA_Livneh
# Directory already exists!
# spooling already done.
# run already done.
#
#
# BCC-CSM2-MR DBCCA_Livneh
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CNRM-ESM2-1 DBCCA_Livneh
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-HR DBCCA_Livneh
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MRI-ESM2-0 DBCCA_Livneh
# Directory already exists!
# spooling already done.
# run already done.
#
#
# NorESM2-MM DBCCA_Livneh
# Directory already exists!
# spooling already done.
# run already done.
#
#
# ACCESS-CM2 RegCM_Livneh
# Directory already exists!
# spooling already done.
# run already done.
#
#
# BCC-CSM2-MR RegCM_Livneh
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CNRM-ESM2-1 RegCM_Livneh
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-HR RegCM_Livneh
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MRI-ESM2-0 RegCM_Livneh
# Directory already exists!
# spooling already done.
# run already done.
#
#
# NorESM2-MM RegCM_Livneh
# Directory already exists!
# spooling already done.
# run already done.

# %% [markdown]
# # Projections

# %% [markdown]
# ### NEX-GDDP

# %%
# Constants
ensemble = "NEX-GDDP"
vars_ = ["tasmin", "tasmax", "pr"]

# Get run infos
run_info = df_climate_drivers[
    (df_climate_drivers.ensemble == ensemble) & (df_climate_drivers.ssp != "historical")
].copy()

# %%
# Simulation length
run_start = "2015-01-01"
run_end = "2099-12-31"

# Spin up
spinup_start = "2015-01-01"
spinup_end = "2015-12-31"
spinup_loops = 5

# Cloud fraction
cloudFr_primary = "merra2_cldtot_dc.init"

# Crop parameter file
crop_par = "CDL-US-M_CropParameters_proj.csv"

# Crop area timeseries
crop_area_frac = "cdl_cropland_proj.init"

# Only used for LOCA2 projections
state_id = ""

# %%
##################
# NEX projections
##################
for _, info in run_info.iterrows():
    if info["model"] in ["HadGEM3-GC31-MM"]:
        if info['ssp'] == 'ssp585':
            print(f"{info['model']} {info['ssp']}")
            sim_ID = f"{info['ensemble']}_{info['model']}_{info['member']}_{info['ssp']}"

            if info['model'] in ["HadGEM3-GC31-LL", "HadGEM3-GC31-MM", "KACE-1-0-G", "UKESM1-0-LL"]:
                calendar = 360
                run_end = "2099-12-30"
                spinup_end = "2015-12-30"
            else:
                calendar = 365
                run_end = "2099-12-31"
                spinup_end = "2015-12-31"

            run_WBM(
                run_type="model",
                main_path=main_path,
                sim_ID=sim_ID,
                run_info=info,
                project_ID=project_ID,
                run_start=run_start,
                run_end=run_end,
                calendar=calendar,
                spinup_start=spinup_start,
                spinup_end=spinup_end,
                spinup_loops=spinup_loops,
                state_id=state_id,
                output_vars=output_vars,
                pet_method=pet_method,
                vars_=vars_,
                airT_primary="XXX",
                airT_secondary="XXX",
                airT_min=f"{sim_ID}_tasmin_daily.init",
                airT_max=f"{sim_ID}_tasmax_daily.init",
                precip_primary=f"{sim_ID}_pr_daily.init",
                precip_secondary="",
                cloudFr_primary=cloudFr_primary,
                windU_primary="",
                windV_primary="",
                humidity_primary="",
                albedo_primary="",
                rootingDepth=rootingDepth,
                soilAWC=soilAWC,
                canopyHt=canopyHt,
                lai=lai,
                land_collapse=land_collapse,
                crop_area_frac=crop_area_frac,
                crop_area_frac_patch="",
                crop_par=crop_par,
                crop_par_patch="",
            )

            print("\n")
# Out:
# HadGEM3-GC31-MM ssp585
# Directory already exists!
# spooling already done.
# run jobid: 44269729

# %% [markdown]
# ### LOCA

# %%
# Constants
ensemble = "LOCA2"
vars_ = ["tasmax", "tasmin", "pr"]

# Get run infos
run_info = df_climate_drivers[
    (df_climate_drivers.ensemble == ensemble) & (df_climate_drivers.ssp != "historical")
].copy()

# %%
### Constant for all runs
# Simulation length
run_starts = ["2015-01-01", "2045-01-01", "2075-01-01"]
run_ends = ["2044-12-31", "2074-12-31", "2100-12-31"]
run_IDs = ["early", "mid", "late"]

# Cloud fraction
cloudFr_primary = "merra2_cldtot_dc.init"

# Crop parameter file
crop_par = "CDL-US-M_CropParameters_proj.csv"

# Crop area timeseries
crop_area_frac = "cdl_cropland_proj.init"

# %%
############################
# LOCA projections: EARLY
############################
# Spin up
spinup_start = "2015-01-01"
spinup_end = "2015-12-31"
spinup_loops = 5
state_id = ""

# Early
time_id = 0

for _, info in run_info.iterrows():
    print(f"{info['model']} {info['member']} {info['ssp']}")
    sim_ID = f"{info['ensemble']}_{info['model']}_{info['member']}_{info['ssp']}_{run_IDs[time_id]}"

    run_WBM(
        run_type="model",
        main_path=main_path,
        sim_ID=sim_ID,
        run_info=info,
        project_ID=project_ID,
        run_start=run_starts[time_id],
        run_end=run_ends[time_id],
        spinup_start=spinup_start,
        spinup_end=spinup_end,
        spinup_loops=spinup_loops,
        state_id=state_id,
        output_vars=output_vars,
        pet_method=pet_method,
        vars_=vars_,
        airT_primary="XXX",
        airT_secondary="XXX",
        airT_min=f"{sim_ID}_tasmin_daily.init",
        airT_max=f"{sim_ID}_tasmax_daily.init",
        precip_primary=f"{sim_ID}_pr_daily.init",
        precip_secondary="",
        cloudFr_primary=cloudFr_primary,
        windU_primary="",
        windV_primary="",
        humidity_primary="",
        albedo_primary="",
        rootingDepth=rootingDepth,
        soilAWC=soilAWC,
        canopyHt=canopyHt,
        lai=lai,
        land_collapse=land_collapse,
        crop_area_frac=crop_area_frac,
        crop_area_frac_patch="",
        crop_par=crop_par,
        crop_par_patch="",
    )
    print("\n")
# Out:
# AWI-CM-1-1-MR r2i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# AWI-CM-1-1-MR r5i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# AWI-CM-1-1-MR r1i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# AWI-CM-1-1-MR r1i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# AWI-CM-1-1-MR r1i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# AWI-CM-1-1-MR r4i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# AWI-CM-1-1-MR r3i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# IPSL-CM6A-LR r2i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# IPSL-CM6A-LR r2i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# IPSL-CM6A-LR r2i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# IPSL-CM6A-LR r5i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# IPSL-CM6A-LR r5i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# IPSL-CM6A-LR r1i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# IPSL-CM6A-LR r1i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# IPSL-CM6A-LR r1i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# IPSL-CM6A-LR r4i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# IPSL-CM6A-LR r4i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# IPSL-CM6A-LR r4i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# IPSL-CM6A-LR r3i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# IPSL-CM6A-LR r3i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# IPSL-CM6A-LR r3i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# IPSL-CM6A-LR r9i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# IPSL-CM6A-LR r8i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# IPSL-CM6A-LR r10i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# IPSL-CM6A-LR r7i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# IPSL-CM6A-LR r6i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# ACCESS-CM2 r2i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# ACCESS-CM2 r2i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# ACCESS-CM2 r2i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# ACCESS-CM2 r1i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# ACCESS-CM2 r1i1p1f1 ssp585
# Directory already exists!
# check jobid: 44238055
# Something went wrong!
#
#
# ACCESS-CM2 r1i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# ACCESS-CM2 r3i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# ACCESS-CM2 r3i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# ACCESS-CM2 r3i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# INM-CM5-0 r2i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# INM-CM5-0 r5i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# INM-CM5-0 r1i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# INM-CM5-0 r1i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# INM-CM5-0 r1i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# INM-CM5-0 r4i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# INM-CM5-0 r3i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# KACE-1-0-G r2i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# KACE-1-0-G r2i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# KACE-1-0-G r2i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# KACE-1-0-G r1i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# KACE-1-0-G r1i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# KACE-1-0-G r1i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# KACE-1-0-G r3i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# KACE-1-0-G r3i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# KACE-1-0-G r3i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-LR r2i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-LR r2i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-LR r2i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-LR r5i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-LR r5i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-LR r5i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-LR r1i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-LR r1i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-LR r1i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-LR r4i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-LR r4i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-LR r4i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-LR r3i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-LR r3i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-LR r3i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-LR r8i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-LR r8i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-LR r8i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-LR r10i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-LR r10i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-LR r10i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-LR r7i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-LR r7i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-LR r7i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-LR r6i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-LR r6i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# NorESM2-LM r2i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# NorESM2-LM r1i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# NorESM2-LM r1i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# NorESM2-LM r1i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# NorESM2-LM r3i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CanESM5 r2i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CanESM5 r2i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CanESM5 r2i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CanESM5 r5i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CanESM5 r5i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CanESM5 r5i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CanESM5 r1i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CanESM5 r1i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CanESM5 r1i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CanESM5 r4i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CanESM5 r4i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CanESM5 r4i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CanESM5 r3i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CanESM5 r3i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CanESM5 r3i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CanESM5 r7i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CanESM5 r7i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CanESM5 r7i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CanESM5 r6i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CanESM5 r6i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CanESM5 r6i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CNRM-CM6-1-HR r1i1p1f2 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# GFDL-ESM4 r1i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# GFDL-ESM4 r1i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# GFDL-ESM4 r1i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CESM2-LENS r2i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CESM2-LENS r5i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CESM2-LENS r1i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CESM2-LENS r4i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CESM2-LENS r3i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CESM2-LENS r9i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CESM2-LENS r8i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CESM2-LENS r10i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CESM2-LENS r7i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CESM2-LENS r6i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# ACCESS-ESM1-5 r2i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# ACCESS-ESM1-5 r2i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# ACCESS-ESM1-5 r2i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# ACCESS-ESM1-5 r5i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# ACCESS-ESM1-5 r5i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# ACCESS-ESM1-5 r5i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# ACCESS-ESM1-5 r1i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# ACCESS-ESM1-5 r1i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# ACCESS-ESM1-5 r1i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# ACCESS-ESM1-5 r4i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# ACCESS-ESM1-5 r4i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# ACCESS-ESM1-5 r4i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# ACCESS-ESM1-5 r3i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# ACCESS-ESM1-5 r3i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# ACCESS-ESM1-5 r3i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# GFDL-CM4 r1i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# GFDL-CM4 r1i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# INM-CM4-8 r1i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# INM-CM4-8 r1i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# INM-CM4-8 r1i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# EC-Earth3 r2i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# EC-Earth3 r1i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# EC-Earth3 r1i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# EC-Earth3 r1i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# EC-Earth3 r4i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# EC-Earth3 r4i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# EC-Earth3 r4i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# EC-Earth3 r3i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# BCC-CSM2-MR r1i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# BCC-CSM2-MR r1i1p1f1 ssp585
# Directory already exists!
# check jobid: 44238057
# Something went wrong!
#
#
# BCC-CSM2-MR r1i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-HR r2i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-HR r2i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-HR r2i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-HR r5i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-HR r1i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-HR r1i1p1f1 ssp585
# Directory already exists!
# check jobid: 44238058
# Something went wrong!
#
#
# MPI-ESM1-2-HR r1i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-HR r4i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-HR r3i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-HR r9i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-HR r8i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-HR r10i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-HR r7i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-HR r6i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# TaiESM1 r1i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# TaiESM1 r1i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# HadGEM3-GC31-LL r2i1p1f3 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# HadGEM3-GC31-LL r1i1p1f3 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# HadGEM3-GC31-LL r1i1p1f3 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# HadGEM3-GC31-LL r3i1p1f3 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# EC-Earth3-Veg r2i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# EC-Earth3-Veg r2i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# EC-Earth3-Veg r2i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# EC-Earth3-Veg r5i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# EC-Earth3-Veg r1i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# EC-Earth3-Veg r1i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# EC-Earth3-Veg r1i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# EC-Earth3-Veg r4i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# EC-Earth3-Veg r4i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# EC-Earth3-Veg r4i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# EC-Earth3-Veg r3i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# EC-Earth3-Veg r3i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# EC-Earth3-Veg r3i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CNRM-CM6-1 r1i1p1f2 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CNRM-CM6-1 r1i1p1f2 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CNRM-CM6-1 r1i1p1f2 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# FGOALS-g3 r5i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# FGOALS-g3 r1i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# FGOALS-g3 r1i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# FGOALS-g3 r1i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# FGOALS-g3 r4i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# FGOALS-g3 r4i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# FGOALS-g3 r4i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# FGOALS-g3 r3i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# FGOALS-g3 r3i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# FGOALS-g3 r3i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# HadGEM3-GC31-MM r2i1p1f3 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# HadGEM3-GC31-MM r1i1p1f3 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MIROC6 r2i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MIROC6 r2i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MIROC6 r2i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MIROC6 r5i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MIROC6 r1i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MIROC6 r1i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MIROC6 r1i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MIROC6 r4i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MIROC6 r3i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MIROC6 r3i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MIROC6 r3i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CNRM-ESM2-1 r1i1p1f2 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CNRM-ESM2-1 r1i1p1f2 ssp585
# Directory already exists!
# check jobid: 44238059
# Something went wrong!
#
#
# CNRM-ESM2-1 r1i1p1f2 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# NorESM2-MM r2i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# NorESM2-MM r1i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run jobid: 44238060
#
#
# NorESM2-MM r1i1p1f1 ssp585
# Directory already exists!
# check jobid: 44238061
# Something went wrong!
#
#
# NorESM2-MM r1i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run jobid: 44238062
#
#
# MRI-ESM2-0 r2i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MRI-ESM2-0 r5i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MRI-ESM2-0 r1i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MRI-ESM2-0 r1i1p1f1 ssp585
# Directory already exists!
# check jobid: 44238063
# Something went wrong!
#
#
# MRI-ESM2-0 r1i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MRI-ESM2-0 r4i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MRI-ESM2-0 r3i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.

# %%
############################
# LOCA projections: MID
############################
# Spin up
spinup_start = ""
spinup_end = ""
spinup_loops = ""
state_id = ""

# Mid
time_id = 1

for _, info in run_info.iterrows():
    print(f"{info['model']} {info['member']} {info['ssp']}")
    sim_ID = f"{info['ensemble']}_{info['model']}_{info['member']}_{info['ssp']}_{run_IDs[time_id]}"

    run_WBM(
        run_type="model",
        main_path=main_path,
        sim_ID=sim_ID,
        run_info=info,
        project_ID=project_ID,
        run_start=run_starts[time_id],
        run_end=run_ends[time_id],
        spinup_start=spinup_start,
        spinup_end=spinup_end,
        spinup_loops=spinup_loops,
        state_id=f"{info['ensemble']}_{info['model']}_{info['member']}_{info['ssp']}_{run_IDs[time_id-1]}",
        output_vars=output_vars,
        pet_method=pet_method,
        vars_=vars_,
        airT_primary="XXX",
        airT_secondary="XXX",
        airT_min=f"{sim_ID}_tasmin_daily.init",
        airT_max=f"{sim_ID}_tasmax_daily.init",
        precip_primary=f"{sim_ID}_pr_daily.init",
        precip_secondary="",
        cloudFr_primary=cloudFr_primary,
        windU_primary="",
        windV_primary="",
        humidity_primary="",
        albedo_primary="",
        rootingDepth=rootingDepth,
        soilAWC=soilAWC,
        canopyHt=canopyHt,
        lai=lai,
        land_collapse=land_collapse,
        crop_area_frac=crop_area_frac,
        crop_area_frac_patch="",
        crop_par=crop_par,
        crop_par_patch="",
    )
    print("\n")
# Out:
# AWI-CM-1-1-MR r2i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# AWI-CM-1-1-MR r5i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# AWI-CM-1-1-MR r1i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# AWI-CM-1-1-MR r1i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# AWI-CM-1-1-MR r1i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# AWI-CM-1-1-MR r4i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# AWI-CM-1-1-MR r3i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# IPSL-CM6A-LR r2i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# IPSL-CM6A-LR r2i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# IPSL-CM6A-LR r2i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# IPSL-CM6A-LR r5i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# IPSL-CM6A-LR r5i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# IPSL-CM6A-LR r1i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# IPSL-CM6A-LR r1i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# IPSL-CM6A-LR r1i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# IPSL-CM6A-LR r4i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# IPSL-CM6A-LR r4i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# IPSL-CM6A-LR r4i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# IPSL-CM6A-LR r3i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# IPSL-CM6A-LR r3i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# IPSL-CM6A-LR r3i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# IPSL-CM6A-LR r9i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# IPSL-CM6A-LR r8i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# IPSL-CM6A-LR r10i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# IPSL-CM6A-LR r7i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# IPSL-CM6A-LR r6i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# ACCESS-CM2 r2i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# ACCESS-CM2 r2i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# ACCESS-CM2 r2i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# ACCESS-CM2 r1i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# ACCESS-CM2 r1i1p1f1 ssp585
# Directory already exists!
# check jobid: 44246973
# spooling already done.
# run already done.
#
#
# ACCESS-CM2 r1i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# ACCESS-CM2 r3i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# ACCESS-CM2 r3i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# ACCESS-CM2 r3i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# INM-CM5-0 r2i1p1f1 ssp370
# check jobid: 44246974
# spool jobid: 44246976
# run jobid: 44246977
#
#
# INM-CM5-0 r5i1p1f1 ssp370
# check jobid: 44246978
# spool jobid: 44246979
# run jobid: 44246980
#
#
# INM-CM5-0 r1i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# INM-CM5-0 r1i1p1f1 ssp585
# check jobid: 44246981
# spool jobid: 44246983
# run jobid: 44246984
#
#
# INM-CM5-0 r1i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# INM-CM5-0 r4i1p1f1 ssp370
# check jobid: 44246985
# spool jobid: 44246986
# run jobid: 44246987
#
#
# INM-CM5-0 r3i1p1f1 ssp370
# check jobid: 44246988
# spool jobid: 44246989
# run jobid: 44246990
#
#
# KACE-1-0-G r2i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# KACE-1-0-G r2i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# KACE-1-0-G r2i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# KACE-1-0-G r1i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# KACE-1-0-G r1i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# KACE-1-0-G r1i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# KACE-1-0-G r3i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# KACE-1-0-G r3i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# KACE-1-0-G r3i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-LR r2i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-LR r2i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-LR r2i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-LR r5i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-LR r5i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-LR r1i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-LR r1i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-LR r1i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-LR r4i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-LR r4i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-LR r3i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-LR r3i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-LR r3i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-LR r8i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-LR r8i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-LR r10i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-LR r10i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-LR r7i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-LR r7i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-LR r6i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# NorESM2-LM r2i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# NorESM2-LM r1i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# NorESM2-LM r1i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# NorESM2-LM r1i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# NorESM2-LM r3i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CanESM5 r2i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CanESM5 r2i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CanESM5 r2i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CanESM5 r5i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CanESM5 r5i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CanESM5 r5i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CanESM5 r1i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CanESM5 r1i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CanESM5 r1i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CanESM5 r4i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CanESM5 r4i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CanESM5 r4i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CanESM5 r3i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CanESM5 r3i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CanESM5 r3i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CanESM5 r7i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CanESM5 r7i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CanESM5 r7i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CanESM5 r6i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CanESM5 r6i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CanESM5 r6i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CNRM-CM6-1-HR r1i1p1f2 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# GFDL-ESM4 r1i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# GFDL-ESM4 r1i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# GFDL-ESM4 r1i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CESM2-LENS r2i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CESM2-LENS r5i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CESM2-LENS r1i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CESM2-LENS r4i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CESM2-LENS r3i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CESM2-LENS r9i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CESM2-LENS r8i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CESM2-LENS r10i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CESM2-LENS r7i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CESM2-LENS r6i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# ACCESS-ESM1-5 r2i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# ACCESS-ESM1-5 r2i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# ACCESS-ESM1-5 r2i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# ACCESS-ESM1-5 r5i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# ACCESS-ESM1-5 r5i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# ACCESS-ESM1-5 r5i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# ACCESS-ESM1-5 r1i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# ACCESS-ESM1-5 r1i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# ACCESS-ESM1-5 r1i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# ACCESS-ESM1-5 r4i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# ACCESS-ESM1-5 r4i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# ACCESS-ESM1-5 r4i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# ACCESS-ESM1-5 r3i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# ACCESS-ESM1-5 r3i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# ACCESS-ESM1-5 r3i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# GFDL-CM4 r1i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# GFDL-CM4 r1i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# INM-CM4-8 r1i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# INM-CM4-8 r1i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# INM-CM4-8 r1i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# EC-Earth3 r2i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# EC-Earth3 r1i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# EC-Earth3 r1i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# EC-Earth3 r1i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# EC-Earth3 r4i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# EC-Earth3 r4i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# EC-Earth3 r4i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# EC-Earth3 r3i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# BCC-CSM2-MR r1i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# BCC-CSM2-MR r1i1p1f1 ssp585
# Directory already exists!
# check jobid: 44246993
# spooling already done.
# run already done.
#
#
# BCC-CSM2-MR r1i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-HR r2i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-HR r2i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-HR r2i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-HR r5i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-HR r1i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-HR r1i1p1f1 ssp585
# Directory already exists!
# check jobid: 44246995
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-HR r1i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-HR r4i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-HR r3i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-HR r9i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-HR r8i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-HR r10i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-HR r7i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-HR r6i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# TaiESM1 r1i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# TaiESM1 r1i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# HadGEM3-GC31-LL r2i1p1f3 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# HadGEM3-GC31-LL r1i1p1f3 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# HadGEM3-GC31-LL r1i1p1f3 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# HadGEM3-GC31-LL r3i1p1f3 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# EC-Earth3-Veg r2i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# EC-Earth3-Veg r2i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# EC-Earth3-Veg r2i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# EC-Earth3-Veg r5i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# EC-Earth3-Veg r1i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# EC-Earth3-Veg r1i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# EC-Earth3-Veg r1i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# EC-Earth3-Veg r4i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# EC-Earth3-Veg r4i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# EC-Earth3-Veg r4i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# EC-Earth3-Veg r3i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# EC-Earth3-Veg r3i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# EC-Earth3-Veg r3i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CNRM-CM6-1 r1i1p1f2 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CNRM-CM6-1 r1i1p1f2 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CNRM-CM6-1 r1i1p1f2 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# FGOALS-g3 r5i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# FGOALS-g3 r1i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# FGOALS-g3 r1i1p1f1 ssp585
# check jobid: 44246997
# spool jobid: 44247001
# run jobid: 44247002
#
#
# FGOALS-g3 r1i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# FGOALS-g3 r4i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# FGOALS-g3 r4i1p1f1 ssp585
# check jobid: 44247003
# spool jobid: 44247007
# run jobid: 44247008
#
#
# FGOALS-g3 r4i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# FGOALS-g3 r3i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# FGOALS-g3 r3i1p1f1 ssp585
# check jobid: 44247009
# spool jobid: 44247010
# run jobid: 44247011
#
#
# FGOALS-g3 r3i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# HadGEM3-GC31-MM r2i1p1f3 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# HadGEM3-GC31-MM r1i1p1f3 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MIROC6 r2i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MIROC6 r2i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MIROC6 r2i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MIROC6 r5i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MIROC6 r1i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MIROC6 r1i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MIROC6 r1i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MIROC6 r4i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MIROC6 r3i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MIROC6 r3i1p1f1 ssp585
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MIROC6 r3i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CNRM-ESM2-1 r1i1p1f2 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# CNRM-ESM2-1 r1i1p1f2 ssp585
# Directory already exists!
# check jobid: 44247012
# spooling already done.
# run already done.
#
#
# CNRM-ESM2-1 r1i1p1f2 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# NorESM2-MM r2i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# NorESM2-MM r1i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# NorESM2-MM r1i1p1f1 ssp585
# Directory already exists!
# check jobid: 44247013
# spooling already done.
# run already done.
#
#
# NorESM2-MM r1i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MRI-ESM2-0 r2i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MRI-ESM2-0 r5i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MRI-ESM2-0 r1i1p1f1 ssp245
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MRI-ESM2-0 r1i1p1f1 ssp585
# Directory already exists!
# check jobid: 44247014
# spooling already done.
# run already done.
#
#
# MRI-ESM2-0 r1i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MRI-ESM2-0 r4i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.
#
#
# MRI-ESM2-0 r3i1p1f1 ssp370
# Directory already exists!
# spooling already done.
# run already done.

# %%
############################
# LOCA projections: LATE
############################
# Spin up
spinup_start = ""
spinup_end = ""
spinup_loops = ""
state_id = ""

# Late
time_id = 2

for _, info in run_info.iterrows():
    print(f"{info['model']} {info['member']} {info['ssp']}")
    sim_ID = f"{info['ensemble']}_{info['model']}_{info['member']}_{info['ssp']}_{run_IDs[time_id]}"

    run_WBM(
        run_type="model",
        main_path=main_path,
        sim_ID=sim_ID,
        run_info=info,
        project_ID=project_ID,
        run_start=run_starts[time_id],
        run_end=run_ends[time_id],
        spinup_start=spinup_start,
        spinup_end=spinup_end,
        spinup_loops=spinup_loops,
        state_id=f"{info['ensemble']}_{info['model']}_{info['member']}_{info['ssp']}_{run_IDs[time_id-1]}",
        output_vars=output_vars,
        pet_method=pet_method,
        vars_=vars_,
        airT_primary="XXX",
        airT_secondary="XXX",
        airT_min=f"{sim_ID}_tasmin_daily.init",
        airT_max=f"{sim_ID}_tasmax_daily.init",
        precip_primary=f"{sim_ID}_pr_daily.init",
        precip_secondary="",
        cloudFr_primary=cloudFr_primary,
        windU_primary="",
        windV_primary="",
        humidity_primary="",
        albedo_primary="",
        rootingDepth=rootingDepth,
        soilAWC=soilAWC,
        canopyHt=canopyHt,
        lai=lai,
        land_collapse=land_collapse,
        crop_area_frac=crop_area_frac,
        crop_area_frac_patch="",
        crop_par=crop_par,
        crop_par_patch="",
    )
    print("\n")
# Out:
# AWI-CM-1-1-MR r2i1p1f1 ssp370
# check jobid: 44251249
# spool jobid: 44251250
# run jobid: 44251251
#
#
# AWI-CM-1-1-MR r5i1p1f1 ssp370
# check jobid: 44251252
# spool jobid: 44251254
# run jobid: 44251255
#
#
# AWI-CM-1-1-MR r1i1p1f1 ssp245
# check jobid: 44251256
# spool jobid: 44251257
# run jobid: 44251258
#
#
# AWI-CM-1-1-MR r1i1p1f1 ssp585
# check jobid: 44251259
# spool jobid: 44251260
# run jobid: 44251261
#
#
# AWI-CM-1-1-MR r1i1p1f1 ssp370
# check jobid: 44251262
# spool jobid: 44251263
# run jobid: 44251264
#
#
# AWI-CM-1-1-MR r4i1p1f1 ssp370
# check jobid: 44251265
# spool jobid: 44251266
# run jobid: 44251267
#
#
# AWI-CM-1-1-MR r3i1p1f1 ssp370
# check jobid: 44251268
# spool jobid: 44251273
# run jobid: 44251275
#
#
# IPSL-CM6A-LR r2i1p1f1 ssp245
# check jobid: 44251277
# spool jobid: 44251288
# run jobid: 44251289
#
#
# IPSL-CM6A-LR r2i1p1f1 ssp585
# check jobid: 44251290
# spool jobid: 44251291
# run jobid: 44251292
#
#
# IPSL-CM6A-LR r2i1p1f1 ssp370
# check jobid: 44251293
# spool jobid: 44251294
# run jobid: 44251295
#
#
# IPSL-CM6A-LR r5i1p1f1 ssp245
# check jobid: 44251296
# spool jobid: 44251298
# run jobid: 44251299
#
#
# IPSL-CM6A-LR r5i1p1f1 ssp370
# check jobid: 44251300
# spool jobid: 44251303
# run jobid: 44251304
#
#
# IPSL-CM6A-LR r1i1p1f1 ssp245
# check jobid: 44251305
# spool jobid: 44251308
# run jobid: 44251309
#
#
# IPSL-CM6A-LR r1i1p1f1 ssp585
# check jobid: 44251310
# spool jobid: 44251311
# run jobid: 44251312
#
#
# IPSL-CM6A-LR r1i1p1f1 ssp370
# check jobid: 44251313
# spool jobid: 44251314
# run jobid: 44251315
#
#
# IPSL-CM6A-LR r4i1p1f1 ssp245
# check jobid: 44251316
# spool jobid: 44251317
# run jobid: 44251318
#
#
# IPSL-CM6A-LR r4i1p1f1 ssp585
# check jobid: 44251319
# spool jobid: 44251321
# run jobid: 44251322
#
#
# IPSL-CM6A-LR r4i1p1f1 ssp370
# check jobid: 44251323
# spool jobid: 44251324
# run jobid: 44251325
#
#
# IPSL-CM6A-LR r3i1p1f1 ssp245
# check jobid: 44251326
# spool jobid: 44251327
# run jobid: 44251328
#
#
# IPSL-CM6A-LR r3i1p1f1 ssp585
# check jobid: 44251329
# spool jobid: 44251330
# run jobid: 44251331
#
#
# IPSL-CM6A-LR r3i1p1f1 ssp370
# check jobid: 44251333
# spool jobid: 44251338
# run jobid: 44251339
#
#
# IPSL-CM6A-LR r9i1p1f1 ssp370
# check jobid: 44251340
# spool jobid: 44251341
# run jobid: 44251342
#
#
# IPSL-CM6A-LR r8i1p1f1 ssp370
# check jobid: 44251343
# Something went wrong!
#
#
# IPSL-CM6A-LR r10i1p1f1 ssp370
# check jobid: 44251345
# spool jobid: 44251346
# run jobid: 44251347
#
#
# IPSL-CM6A-LR r7i1p1f1 ssp370
# check jobid: 44251348
# spool jobid: 44251349
# run jobid: 44251350
#
#
# IPSL-CM6A-LR r6i1p1f1 ssp370
# check jobid: 44251351
# spool jobid: 44251358
# run jobid: 44251360
#
#
# ACCESS-CM2 r2i1p1f1 ssp245
# check jobid: 44251361
# spool jobid: 44251366
# run jobid: 44251367
#
#
# ACCESS-CM2 r2i1p1f1 ssp585
# check jobid: 44251368
# spool jobid: 44251369
# run jobid: 44251370
#
#
# ACCESS-CM2 r2i1p1f1 ssp370
# check jobid: 44251371
# spool jobid: 44251373
# run jobid: 44251374
#
#
# ACCESS-CM2 r1i1p1f1 ssp245
# check jobid: 44251375
# spool jobid: 44251376
# run jobid: 44251377
#
#
# ACCESS-CM2 r1i1p1f1 ssp585
# Directory already exists!
# check jobid: 44251378
# spooling already done.
# run already done.
#
#
# ACCESS-CM2 r1i1p1f1 ssp370
# check jobid: 44251379
# spool jobid: 44251380
# run jobid: 44251381
#
#
# ACCESS-CM2 r3i1p1f1 ssp245
# check jobid: 44251382
# spool jobid: 44251383
# run jobid: 44251384
#
#
# ACCESS-CM2 r3i1p1f1 ssp585
# check jobid: 44251385
# spool jobid: 44251386
# run jobid: 44251387
#
#
# ACCESS-CM2 r3i1p1f1 ssp370
# check jobid: 44251389
# spool jobid: 44251390
# run jobid: 44251391
#
#
# INM-CM5-0 r2i1p1f1 ssp370
# check jobid: 44251392
# spool jobid: 44251393
# run jobid: 44251394
#
#
# INM-CM5-0 r5i1p1f1 ssp370
# check jobid: 44251395
# spool jobid: 44251396
# run jobid: 44251397
#
#
# INM-CM5-0 r1i1p1f1 ssp245
# check jobid: 44251398
# spool jobid: 44251401
# run jobid: 44251402
#
#
# INM-CM5-0 r1i1p1f1 ssp585
# check jobid: 44251403
# spool jobid: 44251404
# run jobid: 44251406
#
#
# INM-CM5-0 r1i1p1f1 ssp370
# check jobid: 44251409
# spool jobid: 44251413
# run jobid: 44251414
#
#
# INM-CM5-0 r4i1p1f1 ssp370
# check jobid: 44251415
# spool jobid: 44251416
# run jobid: 44251417
#
#
# INM-CM5-0 r3i1p1f1 ssp370
# check jobid: 44251418
# spool jobid: 44251420
# run jobid: 44251421
#
#
# KACE-1-0-G r2i1p1f1 ssp245
# check jobid: 44251422
# spool jobid: 44251426
# run jobid: 44251427
#
#
# KACE-1-0-G r2i1p1f1 ssp585
# check jobid: 44251428
# Something went wrong!
#
#
# KACE-1-0-G r2i1p1f1 ssp370
# check jobid: 44251433
# spool jobid: 44251435
# run jobid: 44251436
#
#
# KACE-1-0-G r1i1p1f1 ssp245
# check jobid: 44251437
# spool jobid: 44251438
# run jobid: 44251439
#
#
# KACE-1-0-G r1i1p1f1 ssp585
# check jobid: 44251440
# spool jobid: 44251441
# run jobid: 44251442
#
#
# KACE-1-0-G r1i1p1f1 ssp370
# check jobid: 44251443
# spool jobid: 44251445
# run jobid: 44251446
#
#
# KACE-1-0-G r3i1p1f1 ssp245
# check jobid: 44251447
# spool jobid: 44251448
# run jobid: 44251449
#
#
# KACE-1-0-G r3i1p1f1 ssp585
# check jobid: 44251450
# spool jobid: 44251459
# run jobid: 44251461
#
#
# KACE-1-0-G r3i1p1f1 ssp370
# check jobid: 44251463
# spool jobid: 44251468
# run jobid: 44251469
#
#
# MPI-ESM1-2-LR r2i1p1f1 ssp245
# check jobid: 44251470
# spool jobid: 44251471
# run jobid: 44251472
#
#
# MPI-ESM1-2-LR r2i1p1f1 ssp585
# check jobid: 44251473
# spool jobid: 44251483
# run jobid: 44251485
#
#
# MPI-ESM1-2-LR r2i1p1f1 ssp370
# check jobid: 44251486
# spool jobid: 44251487
# run jobid: 44251488
#
#
# MPI-ESM1-2-LR r5i1p1f1 ssp245
# check jobid: 44251489
# spool jobid: 44251490
# run jobid: 44251492
#
#
# MPI-ESM1-2-LR r5i1p1f1 ssp370
# check jobid: 44251493
# spool jobid: 44251496
# run jobid: 44251497
#
#
# MPI-ESM1-2-LR r1i1p1f1 ssp245
# check jobid: 44251498
# spool jobid: 44251500
# run jobid: 44251501
#
#
# MPI-ESM1-2-LR r1i1p1f1 ssp585
# check jobid: 44251502
# spool jobid: 44251505
# run jobid: 44251506
#
#
# MPI-ESM1-2-LR r1i1p1f1 ssp370
# check jobid: 44251507
# spool jobid: 44251508
# run jobid: 44251509
#
#
# MPI-ESM1-2-LR r4i1p1f1 ssp245
# check jobid: 44251510
# spool jobid: 44251511
# run jobid: 44251512
#
#
# MPI-ESM1-2-LR r4i1p1f1 ssp370
# check jobid: 44251513
# spool jobid: 44251514
# run jobid: 44251515
#
#
# MPI-ESM1-2-LR r3i1p1f1 ssp245
# check jobid: 44251516
# Something went wrong!
#
#
# MPI-ESM1-2-LR r3i1p1f1 ssp585
# check jobid: 44251517
# spool jobid: 44251518
# run jobid: 44251519
#
#
# MPI-ESM1-2-LR r3i1p1f1 ssp370
# check jobid: 44251520
# spool jobid: 44251521
# run jobid: 44251522
#
#
# MPI-ESM1-2-LR r8i1p1f1 ssp245
# check jobid: 44251523
# spool jobid: 44251525
# run jobid: 44251526
#
#
# MPI-ESM1-2-LR r8i1p1f1 ssp370
# check jobid: 44251527
# Something went wrong!
#
#
# MPI-ESM1-2-LR r10i1p1f1 ssp245
# check jobid: 44251530
# spool jobid: 44251531
# run jobid: 44251532
#
#
# MPI-ESM1-2-LR r10i1p1f1 ssp370
# check jobid: 44251533
# spool jobid: 44251541
# run jobid: 44251542
#
#
# MPI-ESM1-2-LR r7i1p1f1 ssp245
# check jobid: 44251543
# spool jobid: 44251551
# run jobid: 44251552
#
#
# MPI-ESM1-2-LR r7i1p1f1 ssp370
# check jobid: 44251553
# spool jobid: 44251555
# run jobid: 44251556
#
#
# MPI-ESM1-2-LR r6i1p1f1 ssp245
# check jobid: 44251557
# spool jobid: 44251559
# run jobid: 44251560
#
#
# NorESM2-LM r2i1p1f1 ssp245
# check jobid: 44251561
# spool jobid: 44251562
# run jobid: 44251563
#
#
# NorESM2-LM r1i1p1f1 ssp245
# check jobid: 44251564
# spool jobid: 44251565
# run jobid: 44251566
#
#
# NorESM2-LM r1i1p1f1 ssp585
# check jobid: 44251567
# spool jobid: 44251574
# run jobid: 44251575
#
#
# NorESM2-LM r1i1p1f1 ssp370
# check jobid: 44251576
# spool jobid: 44251616
# run jobid: 44251617
#
#
# NorESM2-LM r3i1p1f1 ssp245
# check jobid: 44251618
# spool jobid: 44251622
# run jobid: 44251623
#
#
# CanESM5 r2i1p1f1 ssp245
# check jobid: 44251624
# spool jobid: 44251627
# run jobid: 44251628
#
#
# CanESM5 r2i1p1f1 ssp585
# check jobid: 44251629
# spool jobid: 44251631
# run jobid: 44251632
#
#
# CanESM5 r2i1p1f1 ssp370
# check jobid: 44251633
# spool jobid: 44251636
# run jobid: 44251637
#
#
# CanESM5 r5i1p1f1 ssp245
# check jobid: 44251638
# spool jobid: 44251641
# run jobid: 44251642
#
#
# CanESM5 r5i1p1f1 ssp585
# check jobid: 44251643
# spool jobid: 44251645
# run jobid: 44251647
#
#
# CanESM5 r5i1p1f1 ssp370
# check jobid: 44251648
# spool jobid: 44251651
# run jobid: 44251652
#
#
# CanESM5 r1i1p1f1 ssp245
# check jobid: 44251653
# spool jobid: 44251657
# run jobid: 44251658
#
#
# CanESM5 r1i1p1f1 ssp585
# check jobid: 44251659
# spool jobid: 44251660
# run jobid: 44251661
#
#
# CanESM5 r1i1p1f1 ssp370
# check jobid: 44251662
# spool jobid: 44251663
# run jobid: 44251664
#
#
# CanESM5 r4i1p1f1 ssp245
# check jobid: 44251665
# spool jobid: 44251667
# run jobid: 44251668
#
#
# CanESM5 r4i1p1f1 ssp585
# check jobid: 44251669
# spool jobid: 44251672
# run jobid: 44251673
#
#
# CanESM5 r4i1p1f1 ssp370
# check jobid: 44251674
# spool jobid: 44251685
# run jobid: 44251686
#
#
# CanESM5 r3i1p1f1 ssp245
# check jobid: 44251687
# spool jobid: 44251699
# run jobid: 44251701
#
#
# CanESM5 r3i1p1f1 ssp585
# check jobid: 44251703
# spool jobid: 44251725
# run jobid: 44251727
#
#
# CanESM5 r3i1p1f1 ssp370
# check jobid: 44251729
# spool jobid: 44251753
# run jobid: 44251754
#
#
# CanESM5 r7i1p1f1 ssp245
# check jobid: 44251755
# spool jobid: 44251756
# run jobid: 44251757
#
#
# CanESM5 r7i1p1f1 ssp585
# check jobid: 44251758
# spool jobid: 44251762
# run jobid: 44251763
#
#
# CanESM5 r7i1p1f1 ssp370
# check jobid: 44251764
# spool jobid: 44251766
# run jobid: 44251767
#
#
# CanESM5 r6i1p1f1 ssp245
# check jobid: 44251768
# spool jobid: 44251770
# run jobid: 44251771
#
#
# CanESM5 r6i1p1f1 ssp585
# check jobid: 44251772
# spool jobid: 44251775
# run jobid: 44251776
#
#
# CanESM5 r6i1p1f1 ssp370
# check jobid: 44251777
# spool jobid: 44251780
# run jobid: 44251781
#
#
# CNRM-CM6-1-HR r1i1p1f2 ssp585
# check jobid: 44251782
# spool jobid: 44251785
# run jobid: 44251786
#
#
# GFDL-ESM4 r1i1p1f1 ssp245
# check jobid: 44251787
# spool jobid: 44251788
# run jobid: 44251789
#
#
# GFDL-ESM4 r1i1p1f1 ssp585
# check jobid: 44251790
# spool jobid: 44251791
# run jobid: 44251792
#
#
# GFDL-ESM4 r1i1p1f1 ssp370
# check jobid: 44251793
# spool jobid: 44251795
# run jobid: 44251796
#
#
# CESM2-LENS r2i1p1f1 ssp370
# check jobid: 44251797
# spool jobid: 44251798
# run jobid: 44251799
#
#
# CESM2-LENS r5i1p1f1 ssp370
# check jobid: 44251800
# spool jobid: 44251803
# run jobid: 44251804
#
#
# CESM2-LENS r1i1p1f1 ssp370
# check jobid: 44251805
# spool jobid: 44251806
# run jobid: 44251807
#
#
# CESM2-LENS r4i1p1f1 ssp370
# check jobid: 44251808
# spool jobid: 44251812
# run jobid: 44251813
#
#
# CESM2-LENS r3i1p1f1 ssp370
# check jobid: 44251814
# spool jobid: 44251817
# run jobid: 44251818
#
#
# CESM2-LENS r9i1p1f1 ssp370
# check jobid: 44251819
# spool jobid: 44251821
# run jobid: 44251822
#
#
# CESM2-LENS r8i1p1f1 ssp370
# check jobid: 44251823
# spool jobid: 44251824
# run jobid: 44251825
#
#
# CESM2-LENS r10i1p1f1 ssp370
# check jobid: 44251826
# spool jobid: 44251827
# run jobid: 44251828
#
#
# CESM2-LENS r7i1p1f1 ssp370
# check jobid: 44251829
# spool jobid: 44251831
# run jobid: 44251832
#
#
# CESM2-LENS r6i1p1f1 ssp370
# check jobid: 44251833
# spool jobid: 44251835
# run jobid: 44251836
#
#
# ACCESS-ESM1-5 r2i1p1f1 ssp245
# check jobid: 44251837
# spool jobid: 44251838
# run jobid: 44251839
#
#
# ACCESS-ESM1-5 r2i1p1f1 ssp585
# check jobid: 44251840
# spool jobid: 44251906
# run jobid: 44251907
#
#
# ACCESS-ESM1-5 r2i1p1f1 ssp370
# check jobid: 44251908
# spool jobid: 44251910
# run jobid: 44251911
#
#
# ACCESS-ESM1-5 r5i1p1f1 ssp245
# check jobid: 44251912
# spool jobid: 44251914
# run jobid: 44251915
#
#
# ACCESS-ESM1-5 r5i1p1f1 ssp585
# check jobid: 44251917
# spool jobid: 44251919
# run jobid: 44251920
#
#
# ACCESS-ESM1-5 r5i1p1f1 ssp370
# check jobid: 44251921
# spool jobid: 44251922
# run jobid: 44251923
#
#
# ACCESS-ESM1-5 r1i1p1f1 ssp245
# check jobid: 44251924
# spool jobid: 44251926
# run jobid: 44251927
#
#
# ACCESS-ESM1-5 r1i1p1f1 ssp585
# check jobid: 44251928
# spool jobid: 44251931
# run jobid: 44251932
#
#
# ACCESS-ESM1-5 r1i1p1f1 ssp370
# check jobid: 44251933
# spool jobid: 44251936
# run jobid: 44251937
#
#
# ACCESS-ESM1-5 r4i1p1f1 ssp245
# check jobid: 44251938
# spool jobid: 44251939
# run jobid: 44251940
#
#
# ACCESS-ESM1-5 r4i1p1f1 ssp585
# check jobid: 44251941
# spool jobid: 44251943
# run jobid: 44251944
#
#
# ACCESS-ESM1-5 r4i1p1f1 ssp370
# check jobid: 44251945
# spool jobid: 44251946
# run jobid: 44251947
#
#
# ACCESS-ESM1-5 r3i1p1f1 ssp245
# check jobid: 44251948
# spool jobid: 44251950
# run jobid: 44251951
#
#
# ACCESS-ESM1-5 r3i1p1f1 ssp585
# check jobid: 44251952
# spool jobid: 44251955
# run jobid: 44251956
#
#
# ACCESS-ESM1-5 r3i1p1f1 ssp370
# check jobid: 44251957
# spool jobid: 44251959
# run jobid: 44251960
#
#
# GFDL-CM4 r1i1p1f1 ssp245
# check jobid: 44251961
# spool jobid: 44251963
# run jobid: 44251964
#
#
# GFDL-CM4 r1i1p1f1 ssp585
# check jobid: 44251965
# spool jobid: 44251966
# run jobid: 44251967
#
#
# INM-CM4-8 r1i1p1f1 ssp245
# check jobid: 44251968
# spool jobid: 44251970
# run jobid: 44251971
#
#
# INM-CM4-8 r1i1p1f1 ssp585
# check jobid: 44251972
# spool jobid: 44251974
# run jobid: 44251975
#
#
# INM-CM4-8 r1i1p1f1 ssp370
# check jobid: 44251976
# spool jobid: 44251978
# run jobid: 44251979
#
#
# EC-Earth3 r2i1p1f1 ssp245
# check jobid: 44251980
# spool jobid: 44251982
# run jobid: 44251983
#
#
# EC-Earth3 r1i1p1f1 ssp245
# check jobid: 44251984
# spool jobid: 44251985
# run jobid: 44251986
#
#
# EC-Earth3 r1i1p1f1 ssp585
# check jobid: 44251987
# spool jobid: 44251988
# run jobid: 44251989
#
#
# EC-Earth3 r1i1p1f1 ssp370
# check jobid: 44251990
# spool jobid: 44251992
# run jobid: 44251993
#
#
# EC-Earth3 r4i1p1f1 ssp245
# check jobid: 44251994
# spool jobid: 44252061
# run jobid: 44252069
#
#
# EC-Earth3 r4i1p1f1 ssp585
# check jobid: 44252076
# spool jobid: 44252319
# run jobid: 44252331
#
#
# EC-Earth3 r4i1p1f1 ssp370
# check jobid: 44252344
# spool jobid: 44252599
# run jobid: 44252612
#
#
# EC-Earth3 r3i1p1f1 ssp585
# check jobid: 44252625
# spool jobid: 44253005
# run jobid: 44253018
#
#
# BCC-CSM2-MR r1i1p1f1 ssp245
# check jobid: 44253030
# spool jobid: 44253280
# run jobid: 44253292
#
#
# BCC-CSM2-MR r1i1p1f1 ssp585
# Directory already exists!
# check jobid: 44253306
# spooling already done.
# run jobid: 44253318
#
#
# BCC-CSM2-MR r1i1p1f1 ssp370
# check jobid: 44253331
# spool jobid: 44253586
# run jobid: 44253599
#
#
# MPI-ESM1-2-HR r2i1p1f1 ssp245
# check jobid: 44253614
# spool jobid: 44253866
# run jobid: 44253879
#
#
# MPI-ESM1-2-HR r2i1p1f1 ssp585
# check jobid: 44253894
# spool jobid: 44254018
# run jobid: 44254024
#
#
# MPI-ESM1-2-HR r2i1p1f1 ssp370
# check jobid: 44254025
# spool jobid: 44254028
# run jobid: 44254029
#
#
# MPI-ESM1-2-HR r5i1p1f1 ssp370
# check jobid: 44254030
# spool jobid: 44254031
# run jobid: 44254032
#
#
# MPI-ESM1-2-HR r1i1p1f1 ssp245
# check jobid: 44254033
# spool jobid: 44254034
# run jobid: 44254035
#
#
# MPI-ESM1-2-HR r1i1p1f1 ssp585
# Directory already exists!
# check jobid: 44254036
# spooling already done.
# run already done.
#
#
# MPI-ESM1-2-HR r1i1p1f1 ssp370
# check jobid: 44254037
# spool jobid: 44254039
# run jobid: 44254040
#
#
# MPI-ESM1-2-HR r4i1p1f1 ssp370
# check jobid: 44254041
# Something went wrong!
#
#
# MPI-ESM1-2-HR r3i1p1f1 ssp370
# check jobid: 44254043
# spool jobid: 44254045
# run jobid: 44254046
#
#
# MPI-ESM1-2-HR r9i1p1f1 ssp370
# check jobid: 44254047
# spool jobid: 44254048
# run jobid: 44254049
#
#
# MPI-ESM1-2-HR r8i1p1f1 ssp370
# check jobid: 44254051
# spool jobid: 44254053
# run jobid: 44254054
#
#
# MPI-ESM1-2-HR r10i1p1f1 ssp370
# check jobid: 44254056
# spool jobid: 44254057
# run jobid: 44254058
#
#
# MPI-ESM1-2-HR r7i1p1f1 ssp370
# check jobid: 44254059
# spool jobid: 44254060
# run jobid: 44254061
#
#
# MPI-ESM1-2-HR r6i1p1f1 ssp370
# check jobid: 44254062
# spool jobid: 44254064
# run jobid: 44254065
#
#
# TaiESM1 r1i1p1f1 ssp245
# check jobid: 44254066
# spool jobid: 44254067
# run jobid: 44254068
#
#
# TaiESM1 r1i1p1f1 ssp370
# check jobid: 44254069
# spool jobid: 44254070
# run jobid: 44254071
#
#
# HadGEM3-GC31-LL r2i1p1f3 ssp585
# check jobid: 44254072
# spool jobid: 44254073
# run jobid: 44254074
#
#
# HadGEM3-GC31-LL r1i1p1f3 ssp245
# check jobid: 44254075
# spool jobid: 44254076
# run jobid: 44254077
#
#
# HadGEM3-GC31-LL r1i1p1f3 ssp585
# check jobid: 44254078
# spool jobid: 44254080
# run jobid: 44254081
#
#
# HadGEM3-GC31-LL r3i1p1f3 ssp585
# check jobid: 44254082
# spool jobid: 44254083
# run jobid: 44254084
#
#
# EC-Earth3-Veg r2i1p1f1 ssp245
# check jobid: 44254085
# spool jobid: 44254086
# run jobid: 44254087
#
#
# EC-Earth3-Veg r2i1p1f1 ssp585
# check jobid: 44254088
# spool jobid: 44254090
# run jobid: 44254091
#
#
# EC-Earth3-Veg r2i1p1f1 ssp370
# check jobid: 44254093
# spool jobid: 44254094
# run jobid: 44254095
#
#
# EC-Earth3-Veg r5i1p1f1 ssp245
# check jobid: 44254096
# spool jobid: 44254097
# run jobid: 44254099
#
#
# EC-Earth3-Veg r1i1p1f1 ssp245
# check jobid: 44254100
# spool jobid: 44254101
# run jobid: 44254102
#
#
# EC-Earth3-Veg r1i1p1f1 ssp585
# check jobid: 44254103
# spool jobid: 44254105
# run jobid: 44254106
#
#
# EC-Earth3-Veg r1i1p1f1 ssp370
# check jobid: 44254107
# spool jobid: 44254108
# run jobid: 44254109
#
#
# EC-Earth3-Veg r4i1p1f1 ssp245
# check jobid: 44254110
# spool jobid: 44254111
# run jobid: 44254112
#
#
# EC-Earth3-Veg r4i1p1f1 ssp585
# check jobid: 44254113
# spool jobid: 44254116
# run jobid: 44254117
#
#
# EC-Earth3-Veg r4i1p1f1 ssp370
# check jobid: 44254118
# spool jobid: 44254119
# run jobid: 44254120
#
#
# EC-Earth3-Veg r3i1p1f1 ssp245
# check jobid: 44254121
# spool jobid: 44254122
# run jobid: 44254123
#
#
# EC-Earth3-Veg r3i1p1f1 ssp585
# check jobid: 44254124
# spool jobid: 44254125
# run jobid: 44254126
#
#
# EC-Earth3-Veg r3i1p1f1 ssp370
# check jobid: 44254127
# spool jobid: 44254129
# run jobid: 44254130
#
#
# CNRM-CM6-1 r1i1p1f2 ssp245
# check jobid: 44254131
# spool jobid: 44254132
# run jobid: 44254133
#
#
# CNRM-CM6-1 r1i1p1f2 ssp585
# check jobid: 44254134
# spool jobid: 44254136
# run jobid: 44254137
#
#
# CNRM-CM6-1 r1i1p1f2 ssp370
# check jobid: 44254138
# spool jobid: 44254139
# run jobid: 44254140
#
#
# FGOALS-g3 r5i1p1f1 ssp370
# check jobid: 44254141
# spool jobid: 44254142
# run jobid: 44254143
#
#
# FGOALS-g3 r1i1p1f1 ssp245
# check jobid: 44254144
# spool jobid: 44254145
# run jobid: 44254146
#
#
# FGOALS-g3 r1i1p1f1 ssp585
# check jobid: 44254147
# spool jobid: 44254148
# run jobid: 44254149
#
#
# FGOALS-g3 r1i1p1f1 ssp370
# check jobid: 44254150
# spool jobid: 44254151
# run jobid: 44254152
#
#
# FGOALS-g3 r4i1p1f1 ssp245
# check jobid: 44254153
# spool jobid: 44254154
# run jobid: 44254155
#
#
# FGOALS-g3 r4i1p1f1 ssp585
# check jobid: 44254156
# spool jobid: 44254158
# run jobid: 44254159
#
#
# FGOALS-g3 r4i1p1f1 ssp370
# check jobid: 44254160
# spool jobid: 44254161
# run jobid: 44254162
#
#
# FGOALS-g3 r3i1p1f1 ssp245
# check jobid: 44254163
# spool jobid: 44254165
# run jobid: 44254166
#
#
# FGOALS-g3 r3i1p1f1 ssp585
# check jobid: 44254167
# spool jobid: 44254169
# run jobid: 44254170
#
#
# FGOALS-g3 r3i1p1f1 ssp370
# check jobid: 44254171
# spool jobid: 44254172
# run jobid: 44254173
#
#
# HadGEM3-GC31-MM r2i1p1f3 ssp585
# check jobid: 44254174
# spool jobid: 44254176
# run jobid: 44254177
#
#
# HadGEM3-GC31-MM r1i1p1f3 ssp585
# check jobid: 44254178
# spool jobid: 44254179
# run jobid: 44254180
#
#
# MIROC6 r2i1p1f1 ssp245
# check jobid: 44254181
# spool jobid: 44254183
# run jobid: 44254184
#
#
# MIROC6 r2i1p1f1 ssp585
# check jobid: 44254185
# spool jobid: 44254186
# run jobid: 44254188
#
#
# MIROC6 r2i1p1f1 ssp370
# check jobid: 44254189
# spool jobid: 44254190
# run jobid: 44254191
#
#
# MIROC6 r5i1p1f1 ssp585
# check jobid: 44254192
# spool jobid: 44254193
# run jobid: 44254194
#
#
# MIROC6 r1i1p1f1 ssp245
# check jobid: 44254195
# spool jobid: 44254198
# run jobid: 44254199
#
#
# MIROC6 r1i1p1f1 ssp585
# check jobid: 44254200
# spool jobid: 44254201
# run jobid: 44254202
#
#
# MIROC6 r1i1p1f1 ssp370
# check jobid: 44254203
# spool jobid: 44254205
# run jobid: 44254206
#
#
# MIROC6 r4i1p1f1 ssp585
# check jobid: 44254207
# spool jobid: 44254208
# run jobid: 44254209
#
#
# MIROC6 r3i1p1f1 ssp245
# check jobid: 44254210
# spool jobid: 44254211
# run jobid: 44254212
#
#
# MIROC6 r3i1p1f1 ssp585
# check jobid: 44254213
# spool jobid: 44254216
# run jobid: 44254217
#
#
# MIROC6 r3i1p1f1 ssp370
# check jobid: 44254218
# spool jobid: 44254219
# run jobid: 44254220
#
#
# CNRM-ESM2-1 r1i1p1f2 ssp245
# check jobid: 44254221
# spool jobid: 44254222
# run jobid: 44254223
#
#
# CNRM-ESM2-1 r1i1p1f2 ssp585
# Directory already exists!
# check jobid: 44254224
# spooling already done.
# run already done.
#
#
# CNRM-ESM2-1 r1i1p1f2 ssp370
# check jobid: 44254225
# spool jobid: 44254228
# run jobid: 44254229
#
#
# NorESM2-MM r2i1p1f1 ssp245
# check jobid: 44254230
# Something went wrong!
#
#
# NorESM2-MM r1i1p1f1 ssp245
# check jobid: 44254231
# spool jobid: 44254234
# run jobid: 44254235
#
#
# NorESM2-MM r1i1p1f1 ssp585
# Directory already exists!
# check jobid: 44254236
# spooling already done.
# run already done.
#
#
# NorESM2-MM r1i1p1f1 ssp370
# check jobid: 44254237
# spool jobid: 44254238
# run jobid: 44254239
#
#
# MRI-ESM2-0 r2i1p1f1 ssp370
# check jobid: 44254240
# spool jobid: 44254241
# run jobid: 44254242
#
#
# MRI-ESM2-0 r5i1p1f1 ssp370
# check jobid: 44254243
# spool jobid: 44254244
# run jobid: 44254245
#
#
# MRI-ESM2-0 r1i1p1f1 ssp245
# check jobid: 44254246
# spool jobid: 44254247
# run jobid: 44254248
#
#
# MRI-ESM2-0 r1i1p1f1 ssp585
# Directory already exists!
# check jobid: 44254249
# spooling already done.
# run already done.
#
#
# MRI-ESM2-0 r1i1p1f1 ssp370
# check jobid: 44254250
# spool jobid: 44254252
# run jobid: 44254253
#
#
# MRI-ESM2-0 r4i1p1f1 ssp370
# check jobid: 44254254
# spool jobid: 44254257
# run jobid: 44254258
#
#
# MRI-ESM2-0 r3i1p1f1 ssp370
# check jobid: 44254259
# spool jobid: 44254260
# run jobid: 44254261

# %% [markdown]
# ### OakRidge

# %%
# Get run infos
run_info = df_climate_drivers[(df_climate_drivers.ensemble == "OakRidge") & (df_climate_drivers.ssp == "ssp585")].copy()

# Constants
ensemble = "OakRidge"
vars_ = ["tmax", "tmin", "prcp"]

# %%
#####################
# OakRidge hindcasts
#####################
for _, info in run_info.iterrows():
    print(f"{model} {method}")
    sim_ID = f"{info['ensemble']}_{info['model']}_{info['member']}_{info['method']}_{info['ssp']}"

    run_WBM(
        run_type="model",
        main_path=main_path,
        sim_ID=sim_ID,
        run_info=info,
        project_ID=project_ID,
        run_start=run_start,
        run_end=run_end,
        spinup_start=spinup_start,
        spinup_end=spinup_end,
        spinup_loops=spinup_loops,
        state_id=state_id,
        output_vars=output_vars,
        pet_method=pet_method,
        vars_=vars_,
        airT_primary="XXX",
        airT_secondary="XXX",
        airT_min=f"{sim_ID}_tmin_daily.init",
        airT_max=f"{sim_ID}_tmax_daily.init",
        precip_primary=f"{sim_ID}_prcp_daily.init",
        precip_secondary="",
        cloudFr_primary=cloudFr_primary,
        windU_primary="",
        windV_primary="",
        humidity_primary="",
        albedo_primary="",
        rootingDepth=rootingDepth,
        soilAWC=soilAWC,
        canopyHt=canopyHt,
        lai=lai,
        land_collapse=land_collapse,
        crop_area_frac=crop_area_frac,
        crop_area_frac_patch="",
        crop_par=crop_par,
        crop_par_patch="",
    )
    print("\n")
